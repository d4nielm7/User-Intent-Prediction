# %% [markdown]
# # Feature Scaling and Dimensionality Reduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
import matplotlib.gridspec as gridspec
from tabulate import tabulate
from collections import Counter
import plotly.graph_objects as go
from IPython.display import display, HTML

# %%
customer_data = pd.read_csv('../Dataset/customer_data2.csv')
purchase_history = pd.read_csv('../Dataset/purchase_history.csv')
Item_data = pd.read_csv('../Dataset/Item_data2.csv')

# %%
customer_data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'PurchaseCount', 'Days_Since_Last_Purchase',
#        'Total_Transactions_Unique', 'Total_Products_Purchased', 'Total_Spend',
#        'Average_Transaction_Value', 'Unique_Products_Purchased',
#        'Average_Days_Between_Purchases', 'Day_Of_Week', 'Hour',
#        'Monthly_Spending_Mean', 'Monthly_Spending_Std', 'Spending_Trend',
#        'Spender_Category_Num', 'Frequency_Category_Num'],
#       dtype='object')

# %%
customer_data.drop('Unnamed: 0', axis=1, inplace=True)
Item_data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
Item_data.isnull().sum()
# Out:
# ID                0
# ProdID            0
# TimeStamp         0
# Rating            0
# RatingCount       0
# ReviewCount       0
# Category         10
# Brand            89
# Name              0
# ImageURL          0
# Description     917
# Price             0
# Tags              0
# TimeStampDay      0
# Total_Spend       0
# Day_Of_Week       0
# Hour              0
# Year              0
# Month             0
# price_bin         0
# dtype: int64

# %% [markdown]
# ## Feature Scaling

# %%
scaler = StandardScaler()

columns_to_exclude = ['ID', 'Day_Of_Week','Hour','Spender_Category_Num','Frequency_Category_Num']

columns_to_scale = customer_data.columns.difference(columns_to_exclude)

customer_data_scaled = customer_data.copy()

customer_data_scaled[columns_to_scale] = scaler.fit_transform(customer_data_scaled[columns_to_scale])

# %%
customer_data_scaled.head()
# Out:
#     ID  PurchaseCount  Days_Since_Last_Purchase  Total_Transactions_Unique  \
# 0  0.0      11.831577                 -1.593070                  12.104369
# 1  1.0      10.947483                 -1.593070                  10.895081
# 2  2.0      12.656733                 -1.618234                  12.246639
# 3  3.0      11.419000                 -1.593070                  10.895081
# 4  4.0      11.301120                 -1.567905                  11.108485
#
#    Total_Products_Purchased  Total_Spend  Average_Transaction_Value  \
# 0                 12.104369    11.897406                  -0.027248
# 1                 10.895081    13.020007                   0.111256
# 2                 12.246639    13.246028                   0.037307
# 3                 10.895081    11.400917                   0.014252
# 4                 11.108485     8.258724                  -0.183572
#
#    Unique_Products_Purchased  Average_Days_Between_Purchases  Day_Of_Week  \
# ...

# %%
print(customer_data_scaled.columns)
# Out:
# Index(['ID', 'PurchaseCount', 'Days_Since_Last_Purchase',
#        'Total_Transactions_Unique', 'Total_Products_Purchased', 'Total_Spend',
#        'Average_Transaction_Value', 'Unique_Products_Purchased',
#        'Average_Days_Between_Purchases', 'Day_Of_Week', 'Hour',
#        'Monthly_Spending_Mean', 'Monthly_Spending_Std', 'Spending_Trend',
#        'Spender_Category_Num', 'Frequency_Category_Num'],
#       dtype='object')

# %% [markdown]
# ## Dimensionality Reduction

# %%
customer_data_scaled.set_index('ID', inplace=True)
customer_data_scaled.fillna(customer_data_scaled.mean(), inplace=True)

pca = PCA().fit(customer_data_scaled)

explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

    explained_variance_threshold = 0.95
    optimal_k = np.argmax(cumulative_explained_variance >= explained_variance_threshold) + 1

sns.set(rc={'axes.facecolor': '#D3D3D3'}, style='darkgrid')

plt.figure(figsize=(20, 10))

bar_colors = sns.color_palette("cool", len(explained_variance_ratio))

barplot = sns.barplot(x=list(range(1, len(cumulative_explained_variance) + 1)),
                      y=explained_variance_ratio,
                      palette=bar_colors,
                      alpha=0.8)

lineplot, = plt.plot(range(0, len(cumulative_explained_variance)), cumulative_explained_variance,
                     marker='o', linestyle='--', color='#ff6347', linewidth=2)

optimal_k_line = plt.axvline(optimal_k - 1, color='#32cd32', linestyle='--', label=f'Optimal k value = {optimal_k}')

plt.xlabel('Number of Components', fontsize=14)
plt.ylabel('Explained Variance', fontsize=14)
plt.title('Cumulative Variance vs. Number of Components', fontsize=18)

plt.xticks(range(0, len(cumulative_explained_variance)))
plt.legend(handles=[barplot.patches[0], lineplot, optimal_k_line],
           labels=['Explained Variance of Each Component', 'Cumulative Explained Variance', f'Optimal k value = {optimal_k}'],
           loc=(0.62, 0.1),
           frameon=True,
           framealpha=1.0,
           edgecolor='#ff6347')

x_offset = -0.3
y_offset = 0.01
for i, (ev_ratio, cum_ev_ratio) in enumerate(zip(explained_variance_ratio, cumulative_explained_variance)):
    plt.text(i, ev_ratio, f"{ev_ratio:.2f}", ha="center", va="bottom", fontsize=10)
    if i > 0:
        plt.text(i + x_offset, cum_ev_ratio + y_offset, f"{cum_ev_ratio:.2f}", ha="center", va="bottom", fontsize=10)

plt.grid(axis='both')
plt.show()
# Out:
#   Cell In[9], line 9
#     explained_variance_threshold = 0.95
#     ^
# IndentationError: unexpected indent

# %%
pca = PCA(n_components=4)

customer_data_pca = pca.fit_transform(customer_data_scaled)

customer_data_pca = pd.DataFrame(customer_data_pca, columns=['PC'+str(i+1) for i in range(pca.n_components_)])

customer_data_pca.index = customer_data_scaled.index
customer_data_pca.head()

# %%
def highlight_top3(column):
    top3 = column.abs().nlargest(3).index
    return ['background-color:  #ffeacc' if i in top3 else '' for i in column.index]

pc_df = pd.DataFrame(pca.components_.T, columns=['PC{}'.format(i+1) for i in range(pca.n_components_)],  
                     index=customer_data_scaled.columns)

pc_df.style.apply(highlight_top3, axis=0)

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Elbow Method

# %%
scaler = StandardScaler()

data_cleaned_numeric = Item_data.select_dtypes(include=[np.number])
data_scaled = scaler.fit_transform(data_cleaned_numeric)

km = KMeans(init='k-means++', n_init=10, max_iter=100, random_state=0)

fig, ax = plt.subplots(figsize=(12, 5))

visualizer = KElbowVisualizer(km, k=(2, 15), timings=False, ax=ax)

visualizer.fit(data_scaled)

visualizer.show();

# %% [markdown]
# ## Silhouette Method

# %%
def silhouette_analysis(df, start_k, stop_k, figsize=(15, 16)):
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df)

    plt.figure(figsize=figsize)

    grid = gridspec.GridSpec(stop_k - start_k + 1, 2)

    first_plot = plt.subplot(grid[0, :])
    
    sns.set_palette(['darkorange'])

    silhouette_scores = []

    for k in range(start_k, stop_k + 1):
        km = KMeans(n_clusters=k, init='k-means++', n_init=10, max_iter=100, random_state=0)
        km.fit(df_scaled)
        labels = km.predict(df_scaled)
        score = silhouette_score(df_scaled, labels)
        silhouette_scores.append(score)

    best_k = start_k + silhouette_scores.index(max(silhouette_scores))

    plt.plot(range(start_k, stop_k + 1), silhouette_scores, marker='o')
    plt.xticks(range(start_k, stop_k + 1))
    plt.xlabel('Number of clusters (k)')
    plt.ylabel('Silhouette score')
    plt.title('Average Silhouette Score for Different k Values', fontsize=15)

    optimal_k_text = f'The k value with the highest Silhouette score is: {best_k}'
    plt.text(0.95, max(silhouette_scores) - 0.05, optimal_k_text, fontsize=12, verticalalignment='bottom',
             horizontalalignment='left', bbox=dict(facecolor='#fcc36d', edgecolor='#ff6200', boxstyle='round, pad=0.5'))

    colors = sns.color_palette("bright")

    for i in range(start_k, stop_k + 1):
        km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=0)
        row_idx, col_idx = divmod(i - start_k, 2)

        ax = plt.subplot(grid[row_idx + 1, col_idx])

        visualizer = SilhouetteVisualizer(km, colors=colors, ax=ax)
        visualizer.fit(df_scaled)

        score = silhouette_score(df_scaled, km.labels_)
        ax.text(0.97, 0.02, f'Silhouette Score: {score:.2f}', fontsize=12, ha='right',
                transform=ax.transAxes, color='red')

        ax.set_title(f'Silhouette Plot for {i} Clusters', fontsize=15)

    plt.tight_layout()
    plt.show()

# %%
silhouette_analysis(customer_data_pca, 3, 12, figsize=(20, 50))

# %% [markdown]
# ## Kmeans

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', n_init=10, max_iter=100, random_state=0)
kmeans.fit(customer_data_pca)

cluster_frequencies = Counter(kmeans.labels_)

label_mapping = {label: new_label for new_label, (label, _) in 
                 enumerate(cluster_frequencies.most_common())}

new_labels = np.array([label_mapping[label] for label in kmeans.labels_])

customer_data['cluster'] = new_labels

customer_data_pca['cluster'] = new_labels

# %%
customer_data.head()

# %% [markdown]
# ## Clustering Evaluation

# %%
colors = ['#e8000b', '#1ac938', '#023eff', '#ff7f00', '#8e44ad']  

cluster_0 = customer_data_pca[customer_data_pca['cluster'] == 0]
cluster_1 = customer_data_pca[customer_data_pca['cluster'] == 1]
cluster_2 = customer_data_pca[customer_data_pca['cluster'] == 2]
cluster_3 = customer_data_pca[customer_data_pca['cluster'] == 3]
cluster_4 = customer_data_pca[customer_data_pca['cluster'] == 4]

fig = go.Figure()

fig.add_trace(go.Scatter3d(x=cluster_0['PC1'], y=cluster_0['PC2'], z=cluster_0['PC3'], 
                           mode='markers', marker=dict(color=colors[0], size=5, opacity=0.4), name='Cluster 0'))
fig.add_trace(go.Scatter3d(x=cluster_1['PC1'], y=cluster_1['PC2'], z=cluster_1['PC3'], 
                           mode='markers', marker=dict(color=colors[1], size=5, opacity=0.4), name='Cluster 1'))
fig.add_trace(go.Scatter3d(x=cluster_2['PC1'], y=cluster_2['PC2'], z=cluster_2['PC3'], 
                           mode='markers', marker=dict(color=colors[2], size=5, opacity=0.4), name='Cluster 2'))
fig.add_trace(go.Scatter3d(x=cluster_3['PC1'], y=cluster_3['PC2'], z=cluster_3['PC3'], 
                           mode='markers', marker=dict(color=colors[3], size=5, opacity=0.4), name='Cluster 3'))
fig.add_trace(go.Scatter3d(x=cluster_4['PC1'], y=cluster_4['PC2'], z=cluster_4['PC3'], 
                           mode='markers', marker=dict(color=colors[4], size=5, opacity=0.4), name='Cluster 4'))

fig.update_layout(
    title=dict(text='3D Visualization of Customer Clusters in PCA Space', x=0.5),
    scene=dict(
        xaxis=dict(backgroundcolor="#fcf0dc", gridcolor='white', title='PC1'),
        yaxis=dict(backgroundcolor="#fcf0dc", gridcolor='white', title='PC2'),
        zaxis=dict(backgroundcolor="#fcf0dc", gridcolor='white', title='PC3'),
    ),
    width=900,
    height=800
)

fig.show()

# %%
colors = ['#e8000b', '#1ac938', '#023eff', '#ffa500', '#ff34b3']

cluster_percentage = (customer_data['cluster'].value_counts(normalize=True) * 100).reset_index()
cluster_percentage.columns = ['Cluster', 'Percentage']
cluster_percentage.sort_values(by='Cluster', inplace=True)

plt.figure(figsize=(10, 6))
sns.barplot(x='Percentage', y='Cluster', data=cluster_percentage, orient='h', palette=colors)

for index, value in enumerate(cluster_percentage['Percentage']):
    plt.text(value + 0.5, index, f'{value:.2f}%')

plt.title('Distribution of Customers Across Clusters', fontsize=14)
plt.xticks(ticks=np.arange(0, 50, 5))
plt.xlabel('Percentage (%)')

plt.show()
# Out:
# C:\Users\Daniel Matias\AppData\Local\Temp\ipykernel_26196\2139009503.py:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
colors = ['#e8000b', '#1ac938', '#023eff', '#ffa500', '#ff34b3']


cluster_percentage = {
    'Cluster': ['Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'],
    'Percentage': [31.33, 24.02, 22.57, 21.39, 0.69]  # Example percentages for each cluster
}

plt.figure(figsize=(8, 8))
plt.pie(cluster_percentage['Percentage'], labels=cluster_percentage['Cluster'], 
        autopct='%1.2f%%', colors=colors, startangle=140, wedgeprops={'edgecolor': 'black'})

plt.title('Distribution of Customers Across Clusters')

plt.show()

# %%
num_observations = len(customer_data_pca)

X = customer_data_pca.drop('cluster', axis=1)
clusters = customer_data_pca['cluster']

sil_score = silhouette_score(X, clusters)
calinski_score = calinski_harabasz_score(X, clusters)
davies_score = davies_bouldin_score(X, clusters)

table_data = [
    ["Number of Observations", num_observations],
    ["Silhouette Score", sil_score],
    ["Calinski Harabasz Score", calinski_score],
    ["Davies Bouldin Score", davies_score]
]

print(tabulate(table_data, headers=["Metric", "Value"], tablefmt='pretty'))
# Out:
# +-------------------------+--------------------+
# |         Metric          |       Value        |
# +-------------------------+--------------------+
# | Number of Observations  |        1449        |
# |    Silhouette Score     | 0.4597367838037207 |
# | Calinski Harabasz Score | 2939.7800322495577 |
# |  Davies Bouldin Score   | 0.644620911374911  |
# +-------------------------+--------------------+

# %% [markdown]
# ## Clustering Analysis

# %%
num_clusters = len(np.unique(kmeans.labels_))
print(f'Total clusters found: {num_clusters}')
# Out:
# Total clusters found: 5

# %%
df_customer = customer_data.set_index('ID')

scaler = StandardScaler()
df_customer_standardized = scaler.fit_transform(df_customer.drop(columns=['cluster'], axis=1))

df_customer_standardized = pd.DataFrame(df_customer_standardized, columns=df_customer.columns[:-1], index=df_customer.index)
df_customer_standardized['cluster'] = df_customer['cluster']

cluster_centroids = df_customer_standardized.groupby('cluster').mean()

def create_radar_chart(ax, angles, data, color, cluster):
    ax.fill(angles, data, color=color, alpha=0.3)
    ax.plot(angles, data, color=color, linewidth=2)
    ax.set_title(f'Cluster {cluster}', size=18, color=color, y=1.1, weight='bold')

labels = np.array(cluster_centroids.columns)
num_vars = len(labels)

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
labels = np.concatenate((labels, [labels[0]]))
angles += angles[:1]

fig, ax = plt.subplots(figsize=(35, 25), subplot_kw=dict(polar=True), nrows=1, ncols=5)

ax = ax.flatten()

colors = ['#e8000b', '#1ac938', '#023eff', '#ffa500', '#ff34b3']

for i, color in enumerate(colors):
    if i < len(cluster_centroids):
        data = cluster_centroids.loc[i].tolist()
        data += data[:1]
        create_radar_chart(ax[i], angles, data, color, i)
        ax[i].set_xticks(angles[:-1])
        ax[i].set_xticklabels(labels[:-1], fontsize=10, rotation=45)
        ax[i].set_yticklabels([])  # Hide radial axis labels for clarity

ax[0].grid(color='grey', linewidth=0.5)

plt.tight_layout()
plt.show()

# %%
features = customer_data.columns[1:-1]
clusters = sorted(customer_data['cluster'].unique())
n_rows = len(features)
n_cols = len(clusters)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(22, 4*n_rows))

for i, feature in enumerate(features):
    for j, cluster in enumerate(clusters):
        data = customer_data[customer_data['cluster'] == cluster][feature]
        axes[i, j].hist(data, bins=20, color=colors[j], edgecolor='black', alpha=0.7)
        axes[i, j].set_title(f'Cluster {cluster} - {feature}', fontsize=13)
        axes[i, j].tick_params(axis='both', which='major', labelsize=10)
        axes[i, j].set_xlabel(feature, fontsize=10)
        axes[i, j].set_ylabel('Count', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analysis With LLM

# %% [markdown]
# <h2 style="color:#d32f2f; font-family: Arial, sans-serif;">Customer Descriptions and Insights</h2>
#
# <h3 style="color:#f44336; font-family: Arial, sans-serif;"><strong>Cluster 0 - Budget-Conscious Low-Frequency Shoppers</strong></h3>
# <ul style="font-family: Arial, sans-serif;">
#     <li><strong>Profile:</strong> These customers make infrequent purchases with lower transaction values, generally opting for a small range of products. They are conservative in spending.</li>
#     <li><strong>Behavioral Traits:</strong> Preference for weekend shopping, particularly Sundays. Shopping times lean towards early morning, suggesting price sensitivity and cautious purchasing.</li>
#     <li><strong>Recommendation:</strong>
#         <ul>
#             <li>Implement <strong>loyalty programs</strong> offering small rewards to increase engagement.</li>
#             <li>Provide <strong>weekend discounts</strong> to boost spending during their preferred days.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4caf50; font-family: Arial, sans-serif;"><strong>Cluster 1 - Standard Spenders with Evening Shopping Patterns</strong></h3>
# <ul style="font-family: Arial, sans-serif;">
#     <li><strong>Profile:</strong> Moderate spenders with a balanced approach. They neither overspend nor are overly conservative.</li>
#     <li><strong>Behavioral Traits:</strong> Prefer late evening shopping with a steady purchasing pattern throughout the year. Less prone to cancel transactions.</li>
#     <li><strong>Recommendation:</strong>
#         <ul>
#             <li>Utilize <strong>evening-specific promotions</strong> to engage this group.</li>
#             <li>Offer <strong>personalized recommendations</strong> based on past purchases to foster loyalty.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#2196f3; font-family: Arial, sans-serif;"><strong>Cluster 2 - High-Frequency Shoppers with Low Value Transactions</strong></h3>
# <ul style="font-family: Arial, sans-serif;">
#     <li><strong>Profile:</strong> Frequent buyers making multiple transactions with small purchase values. They are keen on finding deals.</li>
#     <li><strong>Behavioral Traits:</strong> Active during early evenings with a focus on low-cost products. Exhibit frequent buying behavior within a limited budget.</li>
#     <li><strong>Recommendation:</strong>
#         <ul>
#             <li>Encourage larger purchases with <strong>flash sales</strong> and <strong>bundle offers</strong>.</li>
#             <li>Offer <strong>time-sensitive discounts</strong> to capitalize on their frequent shopping patterns.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#ff9800; font-family: Arial, sans-serif;"><strong>Cluster 3 - Premium Weekend Shoppers with Varied Habits</strong></h3>
# <ul style="font-family: Arial, sans-serif;">
#     <li><strong>Profile:</strong> High spenders with a preference for premium goods. Their spending habits vary, with occasional high-value transactions, especially on weekends.</li>
#     <li><strong>Behavioral Traits:</strong> Active from mid-morning to early afternoon. Show high variability in purchases, indicating responsiveness to promotions.</li>
#     <li><strong>Recommendation:</strong>
#         <ul>
#             <li>Utilize <strong>personalized offers</strong> to stimulate repeat purchases.</li>
#             <li>Implement <strong>VIP membership</strong> programs for premium product access and early sales notifications.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#9c27b0; font-family: Arial, sans-serif;"><strong>Cluster 4 - Loyal High-Value, Low-Frequency Shoppers</strong></h3>
# <ul style="font-family: Arial, sans-serif;">
#     <li><strong>Profile:</strong> Loyal customers who make occasional but high-value purchases. They prefer bulk buying and often stick to favored brands.</li>
#     <li><strong>Behavioral Traits:</strong> Prefer shopping midweek during midday hours. Their buying is strategic, avoiding crowded shopping times.</li>
#     <li><strong>Recommendation:</strong>
#         <ul>
#             <li>Provide <strong>exclusive membership benefits</strong> to strengthen loyalty.</li>
#             <li>Offer <strong>referral incentives</strong> to attract similar high-value customers.</li>
#         </ul>
#     </li>
# </ul>
#
# <hr style="border-top: 2px solid #ff7043; margin-top: 40px; margin-bottom: 20px;">
#
# <h2 style="color:#ff7043; font-family: Arial, sans-serif;">Conclusion: Leveraging Cluster Insights for Strategic E-commerce Growth</h2>
#
# <p style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
# Based on the analysis of the five identified customer clusters, it is clear that each group exhibits unique shopping patterns, spending behavior, and engagement levels. By understanding these distinct characteristics, e-commerce platforms can tailor strategies to meet the specific needs of each cluster, enhancing customer satisfaction, boosting retention, and driving revenue growth. Below are strategic recommendations designed to optimize engagement and sales across the clusters:
# </p>
#
# <h3 style="color:#d32f2f; font-family: Arial, sans-serif;"><strong>1. Personalization and Incentives for Cost-Conscious Shoppers</strong></h3>
# <ul style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
#     <li><strong>Target Clusters:</strong> Cluster 0 (Budget-Conscious Low-Frequency Shoppers) and Cluster 2 (High-Frequency Shoppers with Low Value Transactions).</li>
#     <li><strong>Strategy:</strong> Introduce tailored loyalty programs that reward frequency and commitment without significantly raising costs. Utilize small discounts and cashback offers for repeat purchases to entice these budget-sensitive shoppers.</li>
#     <li><strong>Action Points:</strong>
#         <ul>
#             <li>Provide <span style="color:#ff9800;">weekend-specific promotions</span> to align with Cluster 0's preference for weekend shopping, boosting activity on low-spending days.</li>
#             <li>Offer <span style="color:#4caf50;">bundle deals and volume-based discounts</span> to Cluster 2, encouraging larger basket sizes without sacrificing their price sensitivity.</li>
#             <li>Use <span style="color:#673ab7;">automated email reminders</span> for abandoned carts to Cluster 2 to recover potential lost sales and drive conversions.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#4caf50; font-family: Arial, sans-serif;"><strong>2. Enhancing Engagement for Moderate and Premium Shoppers</strong></h3>
# <ul style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
#     <li><strong>Target Clusters:</strong> Cluster 1 (Standard Spenders with Evening Shopping Patterns) and Cluster 3 (Premium Weekend Shoppers with Varied Habits).</li>
#     <li><strong>Strategy:</strong> Leverage data-driven marketing to personalize recommendations and enhance customer engagement. Use targeted ads and personalized product suggestions to cater to their specific interests and spending habits.</li>
#     <li><strong>Action Points:</strong>
#         <ul>
#             <li>Send <span style="color:#2196f3;">personalized product suggestions</span> during peak shopping hours for Cluster 1, focusing on their evening shopping behavior.</li>
#             <li>Develop a <span style="color:#ff9800;">VIP membership program</span> for Cluster 3, offering benefits like exclusive early access to sales, premium content, and product launches.</li>
#             <li>Utilize <span style="color:#673ab7;">targeted social media campaigns</span> for high-value products, aimed at Cluster 3's premium spending tendencies.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#2196f3; font-family: Arial, sans-serif;"><strong>3. Optimizing Checkout and Minimizing Purchase Cancellations</strong></h3>
# <ul style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
#     <li><strong>Target Cluster:</strong> Cluster 2 (High-Frequency Shoppers with Low Value Transactions).</li>
#     <li><strong>Strategy:</strong> Improve the checkout experience to reduce abandonment and cancellations. Address common pain points that lead to transaction drops, such as unexpected fees, shipping costs, or slow delivery times.</li>
#     <li><strong>Action Points:</strong>
#         <ul>
#             <li>Implement <span style="color:#d32f2f;">shopping cart reminders</span> and auto-save features to help recover incomplete purchases.</li>
#             <li>Offer <span style="color:#ffeb3b;">free returns and clear refund policies</span> to address concerns around product satisfaction and returns.</li>
#             <li>Introduce a <span style="color:#9c27b0;">subscription-based model</span> for frequently purchased low-cost items, offering convenience and predictability.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#ff9800; font-family: Arial, sans-serif;"><strong>4. Exclusive Offers for Premium and Loyal Shoppers</strong></h3>
# <ul style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
#     <li><strong>Target Cluster:</strong> Cluster 4 (Loyal High-Value, Low-Frequency Shoppers).</li>
#     <li><strong>Strategy:</strong> Build on existing loyalty by offering premium services and exclusive deals that recognize their high value to the brand. Utilize their loyalty to foster brand advocacy.</li>
#     <li><strong>Action Points:</strong>
#         <ul>
#             <li>Provide <span style="color:#ff5722;">exclusive discounts and previews</span> for new product launches, targeting midweek purchases.</li>
#             <li>Implement a <span style="color:#009688;">referral program</span> to encourage word-of-mouth marketing from these high-value customers.</li>
#             <li>Offer <span style="color:#3f51b5;">tiered loyalty benefits</span> such as free shipping, gifts, or extended warranties for continued patronage.</li>
#         </ul>
#     </li>
# </ul>
#
# <h3 style="color:#673ab7; font-family: Arial, sans-serif;"><strong>5. Boosting Revenue Through Time-Sensitive Promotions</strong></h3>
# <ul style="font-family: Arial, sans-serif; line-height: 1.8; font-size: 16px; color: #555555;">
#     <li><strong>Target Cluster:</strong> Cluster 3 (Premium Weekend Shoppers with Varied Habits).</li>
#     <li><strong>Strategy:</strong> Maximize the impact of flash sales, promotions, and limited-time offers to drive spontaneous purchases. Focus on mid-morning to early afternoon shopping habits.</li>
#     <li><strong>Action Points:</strong>
#         <ul>
#             <li>Offer <span style="color:#ff9800;">time-sensitive discounts</span> during weekends to capitalize on their willingness to spend during these periods.</li>
#             <li>Use <span style="color:#ff5722;">personalized offers</span> based on previous high-value purchases to encourage similar future transactions.</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# <h1>Using Chatgpt for further insights on analyzing the graph </h1>

# %% [markdown]
# <h3> Harnessing the Power of LLMs in Practice: A Survey on
#  ChatGPT and Beyond</h3>
#
# Harnessing LLMs for Real-World Applications: The survey on LLMs, such as ChatGPT, highlights the evolution and strengths of these models in practical NLP tasks. LLMs like GPT excel at interpreting complex, structured, and unstructured data, such as text, graphs, and customer behaviors. This aligns well with your use of LLMs to analyze cluster data, as these models can process various data dimensions, such as purchasing patterns and behavioral traits, to produce actionable insights. Furthermore, the study illustrates how LLMs, through proper prompting, can outperform traditional methods in providing tailored and precise responses, ensuring more accurate insights into data

# %% [markdown]
# <h3>Let Your Graph Do the Talking: Encoding Structured Data for LLMs</h3>
# Reasoning and In-Context Learning: LLMs also excel in tasks that require reasoning, as indicated in the articles. By employing in-context learning and few-shot learning, models like ChatGPT can produce logical insights from diverse datasets, including graphs. This explains why, when used effectively with good prompts, LLMs can achieve superior results in data analysis and visual interpretation. Your clustering insights are an excellent example of this, where a well-crafted prompt enabled the model to provide detailed customer insights that would otherwise require significant manual intervention

# %% [markdown]
# According to studies in e-commerce, LLMs and big data analytics are essential for businesses to adapt to rapidly changing environments. Firms that can quickly process customer behavior and transaction patterns through data visualization (like cluster graphs) are better positioned to make dynamic, data-driven decisions. This leads to enhanced competitive advantage and innovation in customer engagement strategies (Erevelles et al. 2016; Rialti et al. 2019). LLMs play a pivotal role by interpreting these complex datasets, offering insights on customer clusters that can drive targeted marketing campaigns, product recommendations, and loyalty programs

# %% [markdown]
# <h3>LLMs and Predictive Customer Segmentation:</h3>
# Research from ACM Transactions on Intelligent Systems and Technology highlights the role of machine learning models in predictive customer behavior analysis. When combined with large datasets, LLMs enable precise customer segmentation based on historical data, purchase patterns, and engagement. This aligns with the example of your e-commerce analysis, where clusters of shoppers exhibit distinct purchasing behaviors.

# %% [markdown]
# # Downloads

# %%
customer_data.to_csv('../Dataset/customer_data_final.csv', index=False)
customer_data_pca.to_csv('../Dataset/customer_data_pca.csv', index=False)
