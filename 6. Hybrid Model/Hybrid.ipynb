# %% [markdown]
# # Hybrid Based Filtering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from surprise import Reader, Dataset, SVD
from surprise.model_selection import train_test_split, GridSearchCV, cross_validate
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import MinMaxScaler
from nltk.stem import PorterStemmer
import string

from IPython.display import display, clear_output, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
import warnings; warnings.simplefilter('ignore')
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
customer_data = pd.read_csv('../Dataset/customer_data_final.csv')
purchase_history = pd.read_csv('../Dataset/purchase_history.csv')
df = pd.read_csv('../Dataset/Item_data2.csv')

# %% [markdown]
# ### Preprocessing

# %%
df['Combined_Text'] = (
        df['Name'].fillna('') + ' ' +
        df['Description'].fillna('') + ' ' +
        df['Tags'].fillna('') + ' ' +
        df['Brand'].fillna('') + ' ' +
        df['Category'].fillna('')
    )

# %% [markdown]
# ## Content based

# %%
def compute_cosine_similarity(data):
    tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), stop_words='english')
    tfidf_matrix = tf.fit_transform(data['Combined_Text'])

    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
    
    return cosine_sim


cosine_sim = compute_cosine_similarity(df)

# %% [markdown]
# ## Collaborative Based

# %%
def train_svd_model_with_tuning(ground_truth_clean):
    reader = Reader()
    data = Dataset.load_from_df(ground_truth_clean[['ID', 'ProdID_List', 'Rating']], reader)

    param_grid = {
        'n_factors': [50, 100, 150],     
        'n_epochs': [10, 20, 30],        
        'lr_all': [0.005, 0.01, 0.02],    
        'reg_all': [0.02, 0.05, 0.1]     
    }

    grid_search = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=5, n_jobs=-1)
    
    grid_search.fit(data)
    
    best_params = grid_search.best_params['rmse']
    print("Best RMSE score:", grid_search.best_score['rmse'])
    print("Best parameters:", best_params)
    
    best_svd = grid_search.best_estimator['rmse']
    trainset, testset = train_test_split(data, test_size=0.2)
    best_svd.fit(trainset)
    
    results = cross_validate(best_svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
    mean_rmse = results['test_rmse'].mean()
    mean_mae = results['test_mae'].mean()
    
    print(f"Mean RMSE across folds: {mean_rmse}")
    print(f"Mean MAE across folds: {mean_mae}")
    
    return best_svd


svd = train_svd_model_with_tuning(purchase_history)
# Out:
# Best RMSE score: 1.2693900549412913
# Best parameters: {'n_factors': 150, 'n_epochs': 30, 'lr_all': 0.005, 'reg_all': 0.02}
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.2715  1.2684  1.2794  1.2829  1.2635  1.2731  0.0071
# MAE (testset)     1.0001  0.9970  0.9913  1.0011  0.9858  0.9951  0.0057
# Fit time          0.05    0.06    0.05    0.04    0.04    0.05    0.01
# Test time         0.00    0.00    0.01    0.00    0.00    0.00    0.00
# Mean RMSE across folds: 1.2731418427633945
# Mean MAE across folds: 0.9950809222002128

# %% [markdown]
# # Mapping Both

# %%
def map_product_indices(data):
    data = data.reset_index()

    indices = pd.Series(data.index, index=data['Name']).drop_duplicates()
    
    id_map = data[['ProdID', 'Name']]
    
    id_map = id_map.set_index('Name')
    
    indices_map = id_map.set_index('ProdID')
    
    return indices, indices_map

indices, indices_map = map_product_indices(df)
print(indices.head(10))       
print(indices_map.head())
# Out:
# Name
# Totally Products Apple Cider Vinegar High Potency (120 Capsules)                                                                                                         0
# LOreal Paris Excellence Creme Triple Protection Color Creame 100% Gray Coverage Natural Ash Black Cooler 3A Hair Color, 1 Kt                                             1
# Garnier Nutrisse Nourishing Hair Color Creme (Browns), 41 Dark Nude Brown, 1 kit                                                                                         2
# Sensationail Gel Nail Color Polish &quotFuchsia Fab&quot, Red Gel Color, 0.25 fl oz (7.39 mL) (Packaging May Vary)                                                       3
# 2 Pack Air Purifying Bag Bamboo Charcoal Air Freshener Deodorizer Odor Eliminator Odor Absorber for Car and Closet 0.11lb/Pack                                           4
# Wet Dry Unisex Painless Stainless Steel Blade Men Women s Fashion Personal Face Grooming Care Electric Nose Ear Face Nose Hair Removal Trimmer Shaver Clipper Remover    5
# (3 pack) Dr Teals Exfoliate & Renew with Eucalyptus & Spearmint Epsom Salt Body Scrub, 16 oz                                                                             6
# Luxury Shower Cap for Women- Most Comfortable Fit, Waterproof & Mold Resistant, Reusable Shower Caps by Kitsch (Floral)                                                  7
# Clairol Natural Instincts Demi-Permanent Hair Color Creme 5R Medium Auburn, 1 Application                                                                                8
# ($50 Value) Proactiv Renewing Acne Cleanser, Face Wash for Acne Prone Skin, 4 Oz - 2 Pack                                                                                9
# dtype: int64
# Empty DataFrame
# Columns: []
# Index: [585.0, 6.0, 1.0, 532.0, 20.0]

# %% [markdown]
# ## Hybrid Based

# %%
def hybrid_recommendation(UserID, product_name, indices, data_cleaned, cosine_sim, svd, display=10):
    if product_name in indices:
        idx = indices[product_name]
    else:
        raise ValueError(f"Product '{product_name}' not found in indices.")
    
    sim_scores = list(enumerate(cosine_sim[int(idx)]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]

    max_index = len(data_cleaned) - 1
    product_indices = [i[0] for i in sim_scores if i[0] <= max_index]
    
    if not product_indices:
        raise ValueError(f"No valid product indices found for '{product_name}'.")
    
    products = df.iloc[product_indices][['ProdID', 'Name', 'Rating', 'Price']]
    
    products['est'] = products['ProdID'].apply(lambda x: svd.predict(UserID, x).est)
    
    products = products.sort_values('est', ascending=False)
    
    return products.head(display), product_indices

# %% [markdown]
# ### Example 1

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    1, 
    'LOreal Paris Excellence Creme Triple Protection Color Creame 100% Gray Coverage Natural Ash Black Cooler 3A Hair Color, 1 Kt', 
    indices, 
    df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#       ProdID                                               Name  Rating  \
# 2966     7.0  Loreal Loreal Healthy Look Sublime Mousse Perm...     3.1
# 3653     7.0  LOreal Paris Excellence Creme Permanent Triple...     4.0
# 3711    35.0  LOreal Superior Preference - 6 Light Brown (Na...     3.3
# 2786     5.0  LOreal Superior Preference Les Blondissimes, L...     3.0
# 1493    68.0  Garnier Nutrisse Haircolor Creme, Black [10] 1...     2.7
# 643      8.0  LOreal Excellence Creme, Medium Brown [5] 1 Ea...     2.9
# 2745     8.0  Garnier Nutrisse Nourishing Hair Color Creme, ...     4.0
# 1226     8.0  LOreal Paris Excellence Creme Triple Protectio...     5.0
# 2802     9.0  LOreal Superior Preference - 8-1/2A Champagne ...     2.9
# 59    6418.0          Creme of Nature Colors Hair Color, 1 each     4.0
#
#       Price       est
# 2966  15.00  5.000000
# 3653   7.91  5.000000
# 3711  33.36  4.302913
# 2786  24.76  4.022856
# 1493  47.78  3.626445
# 643   23.47  3.292576
# 2745   6.97  3.292576
# 1226  62.81  3.292576
# 2802  32.97  3.083447
# 59     9.99  3.069644

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    2, 
    'LOreal Paris Excellence Creme Triple Protection Color Creame 100% Gray Coverage Natural Ash Black Cooler 3A Hair Color, 1 Kt', 
    indices, 
    df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#       ProdID                                               Name  Rating  \
# 2755     2.0  JUST FOR MEN Color Gel Mustache & Beard M-35 M...     3.2
# 2        1.0  Garnier Nutrisse Nourishing Hair Color Creme (...     3.9
# 2811     1.0  Garnier Nutrisse Nourishing Hair Color Creme, ...     4.0
# 2666    77.0  Garnier Nutrisse Nourishing Hair Color Creme (...     4.0
# 1903     6.0  LOreal Paris Superior Preference Fade-Defying ...     3.7
# 2786     5.0  LOreal Superior Preference Les Blondissimes, L...     3.0
# 731      4.0  LOreal Superior Preference - 9-1/2A Lightest A...     3.2
# 1703    61.0  LOreal Excellence Creme - 9-1/2NB Lightest Nat...     5.0
# 2802     9.0  LOreal Superior Preference - 8-1/2A Champagne ...     2.9
# 3711    35.0  LOreal Superior Preference - 6 Light Brown (Na...     3.3
#
#       Price       est
# 2755  40.68  5.000000
# 2      4.44  5.000000
# 2811   6.97  5.000000
# 2666   6.63  4.293477
# 1903   8.97  4.157747
# 2786  24.76  4.002225
# 731   41.96  3.998054
# 1703  34.24  3.235086
# 2802  32.97  3.078569
# 3711  33.36  3.027807

# %% [markdown]
# ### Example 2

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    1, 
    'Luxury Shower Cap for Women- Most Comfortable Fit, Waterproof & Mold Resistant, Reusable Shower Caps by Kitsch (Floral)', 
    indices, 
    df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#             ProdID                                               Name  Rating  \
# 440   7.000000e+00  Thierry Mugler Angel Womens 7-ounce Shower Gel...     3.3
# 3272  7.000000e+00       Cedrat (Citron) Fresh Shower Gel-200ml/6.6oz     3.3
# 578   3.000000e+00  Neutrogena Rainbath Replenishing Shower/Bath G...     4.6
# 2205  1.111104e+39  Dove Shower Foam Body Wash Sensitive Skin 13.5 oz     4.5
# 3676  4.770000e+02  Alpha Keri Shower & Bath Moisture Rich Oil, 16 oz     4.0
# 3904  1.001111e+42  (2 pack) Caress Botanicals Midnight Iris and V...     4.4
# 353   6.010500e+04  Wrapables Stylish Double Layer Waterproof Show...     4.9
# 38    4.800000e+01  Zodaca Baby Kid Children Soft Shampoo Bath Sho...     2.0
# 4021  4.720000e+02                Le Male All-Over Shower Gel, 6.8 Oz     2.0
# 3971  4.819000e+03  Bvlgari Aqva Divina Bath & Shower Gel 3.4 oz -...     3.0
#
#       Price       est
# 440   48.49  5.000000
# 3272  26.31  5.000000
# 578    9.97  5.000000
# 2205   5.94  3.729867
# 3676  15.16  3.576456
# 3904  10.54  3.487550
# 353   14.99  3.384938
# 38     5.99  3.288553
# 4021  36.99  3.113573
# 3971  19.76  3.111748

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    2, 
    'Luxury Shower Cap for Women- Most Comfortable Fit, Waterproof & Mold Resistant, Reusable Shower Caps by Kitsch (Floral)', 
    indices, 
    df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#             ProdID                                               Name  Rating  \
# 1063  2.000000e+00  Molton Brown Relaxing Ylang-Ylang Bath & Showe...     3.2
# 2977  7.940046e+39                         AXE Apollo Body Wash 32 oz     4.7
# 2224  6.000000e+00  Crabtree & Evelyn Rosewater Bath and Shower Ge...     3.0
# 2840  1.005509e+42           The Right To Shower Body Wash Joy, 16 oz     5.0
# 3971  4.819000e+03  Bvlgari Aqva Divina Bath & Shower Gel 3.4 oz -...     3.0
# 1735  4.750000e+02  Bvlgari au the blanc (white tea) Shampoo and S...     3.0
# 3904  1.001111e+42  (2 pack) Caress Botanicals Midnight Iris and V...     4.4
# 2205  1.111104e+39  Dove Shower Foam Body Wash Sensitive Skin 13.5 oz     4.5
# 3485  6.830000e+02  Kiehls Bath & Shower Liquid Body Cleanser - Co...     2.5
# 1102  9.000000e+00  Neutrogena Rainbath Refreshing and Cleansing S...     4.7
#
#       Price       est
# 1063  32.00  5.000000
# 2977   6.97  4.438592
# 2224  29.97  4.157747
# 2840   8.99  3.336826
# 3971  19.76  3.260731
# 1735  36.97  3.173027
# 3904  10.54  3.143117
# 2205   5.94  3.142302
# 3485  25.76  3.116806
# 1102   9.97  3.078569

# %% [markdown]
# ### Example 3

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    1, 
    'Clairol Natural Instincts Demi-Permanent Hair Color Creme 5R Medium Auburn, 1 Application', 
    indices, 
       df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#             ProdID                                               Name  Rating  \
# 3731  5.000000e+00  Clairol Nicen Easy Permanent Hair Color Crème ...     3.1
# 12    2.890000e+02  Clairol Professional Beautiful Collection Semi...     5.0
# 1503  9.886928e+09  Clairol Natural Instincts Hair Color 12A Light...     3.9
# 3956  1.300000e+01  Clairol Natural Instincts Demi-Permanent Hair ...     3.6
# 1399  8.000000e+00  Clairol Nice N Easy Permanent Color 7/106A Nat...     4.5
# 2877  2.990800e+05  Clairol Natural Instincts Hair Color, 7GR Ligh...     5.0
# 903   1.100000e+02  Clairol Natural Instincts Demi-Permanent Hair ...     3.6
# 2819  6.489000e+03  LOreal Paris Superior Preference Fade-Defying ...     3.7
# 329   9.000000e+00  Clairol Nice n Easy Permanent Hair Color, Natu...     4.5
# 4062  2.268000e+03  Clairol Nice n Easy Permanent Hair Color Creme...     4.5
#
#       Price       est
# 3731   6.92  4.022856
# 12     8.42  3.487840
# 1503   6.49  3.389619
# 3956   6.99  3.352004
# 1399   7.99  3.292576
# 2877  18.99  3.285941
# 903    6.92  3.230588
# 2819   8.97  3.108005
# 329    7.29  3.083447
# 4062   6.92  3.069644

# %%
# Example call:
recommendations, product_indices = hybrid_recommendation(
    2, 
    'Clairol Natural Instincts Demi-Permanent Hair Color Creme 5R Medium Auburn, 1 Application', 
    indices, 
    df, 
    cosine_sim, 
    svd, 
    display=10
)

# View recommendations
recommendations
# Out:
#             ProdID                                               Name  Rating  \
# 2319  2.000000e+00  Clairol Natural Instincts Demi-Permanent Hair ...     3.7
# 1918  1.000000e+00  Clairol Natural Instincts Demi-Permanent Hair ...     3.7
# 2666  7.700000e+01  Garnier Nutrisse Nourishing Hair Color Creme (...     4.0
# 4033  8.800000e+01  Clairol Nice N Easy Permanent Hair Color Creme...     4.5
# 1029  6.000000e+00  Clairol Nicen Easy Permanent Hair Color Crème ...     4.5
# 3731  5.000000e+00  Clairol Nicen Easy Permanent Hair Color Crème ...     3.1
# 2993  7.600000e+01  LOreal Paris Superior Preference Fade-Defying ...     3.8
# 1503  9.886928e+09  Clairol Natural Instincts Hair Color 12A Light...     3.9
# 12    2.890000e+02  Clairol Professional Beautiful Collection Semi...     5.0
# 239   5.300000e+01  Clairol nice n easy permanent hair color 4/120...     4.5
#
#       Price       est
# 2319   8.58  5.000000
# 1918   6.99  5.000000
# 2666   6.63  4.293477
# 4033   6.92  4.177925
# 1029   6.92  4.157747
# 3731   6.92  4.002225
# 2993   8.97  3.984637
# 1503   6.49  3.633868
# 12     8.42  3.505557
# 239    7.10  3.390772

# %%
import pickle

with open('hybrid_svd_model.pkl', 'wb') as f:
    pickle.dump(svd, f)
